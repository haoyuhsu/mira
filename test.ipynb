# %%
import pickle
import os

# %%
path = 'stack-boxes-train/color'
fname = '000000-0.pkl'

# %%
data = pickle.load(open(os.path.join(path, fname), 'rb'))

# %%
data.shape
# Out:
# (14, 4, 480, 640, 3)

# %%
step = 0
cam_view = 0

# display rgb image
import matplotlib.pyplot as plt
plt.imshow(data[step, cam_view, :, :, :])
